# %% [markdown]
# ### How to extract last character from names
#
# Need to read in a file of Chinese names and for each name, extract just the last character.  It's tricky because these are unicode strings, so the string needs to be decoded before you can inspect individual characters.

# %%
name_data = open('chinese_names.clean', 'rb').readlines()
sample = name_data[0].strip()  # need to remove the \n from each entry'd line-ending
print sample.decode('utf-8')[-1]
# Out:
# 市

# %% [markdown]
# ### Analyze Chinese names last characters
#
# So the question now is, what are the unique last characters in these Chinese names?  These *should* represent the suffixes for things like "city" or "state" etc.

# %%
from collections import defaultdict

name_dict = defaultdict(int)

for name in name_data:
    name = name.strip()
    last_char = name.decode('utf-8')[-1]
    name_dict[last_char] += 1
    
for char, count in name_dict.items():
    print char, count
# Out:
# 省 23
# 市 656
# 划 5
# 盟 3
# 旗 52
# 区 1244
# 县 1495
# 州 30

# %% [markdown]
# Here are the translations for each one of those:
#
# `
# 省 23   <-- "province"
# 市 656  <-- "city"
# 划 5    <-- "draw" (omit)
# 盟 3    <-- "league"
# 旗 52   <-- "flag" (omit)
# 区 1244 <-- "district", "area", or "prefecture"
# 县 1495 <-- "county"
# 州 30   <-- "state"
# `

# %%
import csv

# remove the 2 entries we can omit
name_dict.pop(u'划')
name_dict.pop(u'旗')

for char, count in name_dict.items():
    print char, count
# Out:
# 省 23
# 市 656
# 盟 3
# 区 1244
# 县 1495
# 州 30

# %% [markdown]
# ### Look for Names in FDB with the unique last characters in them

# %%
# open FDB source files
city_data = open('fdb_city_names.csv', 'rb')
city_reader = csv.reader(city_data, delimiter='|')
next(city_reader)

test_chars = name_dict.keys()

check_city = {}

for city in city_reader:
    id = city[0]
    name = city[1].decode('utf-8')
    last_char = name[-1]
    if len(name) > 2:
        for char in test_chars:
            if char == last_char:
                #print id, name
                check_city[id] = name

# %%
# open pg_dev source files
county_data = open('fdb_county_names.csv', 'rb')
county_reader = csv.reader(county_data, delimiter='|')
next(county_reader)

test_chars = name_dict.keys()

check_county = {}

for county in county_reader:
    id = county[0]
    name = county[1].decode('utf-8')
    last_char = name[-1]
    if len(name) > 2:
        for char in test_chars:
            if char == last_char:
                #print id, name
                check_county[id] = name

# %% [markdown]
# ### Check for presence of existing short-form synonyms
#
# Compare "check_city" and "check_county" to the contents of CitySynonyms and CountySynonyms.  Look for whether an entry exists in the names set that matches the "check" name minus the last character.

# %%
# open the FDB files
CitySynonyms_data = open('CitySynonyms.csv', 'rb')
CitySynonyms = csv.reader(CitySynonyms_data, delimiter='|')
next(CitySynonyms)

check_CitySynonyms = defaultdict(list)

for city in CitySynonyms:
    [id, name, locale, canonical, map_code] = city
    name = name.decode('utf-8')
    if map_code == '1':
        check_CitySynonyms[id].append(name)

print check_CitySynonyms['456607']
# Out:
# [u'Beijing', u'P\xe9kin', u'\u5317\u4eac', u'\ubca0\uc774\uc9d5', u'\u5317\u4eac', u'Beijing', u'Peking']

# %%
# open the FDB files
CountySynonyms_data = open('CountySynonyms.csv', 'rb')
CountySynonyms = csv.reader(CountySynonyms_data, delimiter='|')
next(CountySynonyms)

check_CountySynonyms = defaultdict(list)

for county in CountySynonyms:
    [id, name, locale, canonical, map_code] = county
    name = name.decode('utf-8')
    if map_code == '1':
        check_CountySynonyms[id].append(name)

print check_CountySynonyms['1073884']
# Out:
# [u'Beijing', u'P\xe9kin', u'\u5317\u4eac', u'\ubca0\uc774\uc9d5', u'\u5317\u4eac\u5e02', u'Beijing', u'Peking', u'\u5317\u4eac']

# %% [markdown]
# ### Remove existing synonym-features from processing list
#
# Since we already have short-form names for these, remove them from the list of features that we need to process.

# %%
print check_county['456057']

ok_cities = set()
ok_counties = set()

for id, name in check_city.iteritems():
    last_char = name[-1]
    short_name = name[:-1]
    for known_name in check_CitySynonyms[id]:
        if known_name == short_name:
            ok_cities.add(id)
            
for id, name in check_county.iteritems():
    last_char = name[-1]
    short_name = name[:-1]
    for known_name in check_CountySynonyms[id]:
        if known_name == short_name:
            ok_counties.add(id)            

for id in ok_cities:
    check_city.pop(id)

for id in ok_counties:
    check_county.pop(id)
# Out:
# 石嘴山市

# %% [markdown]
# ### What's the damage?
#
# How many features are going to need new synonyms?

# %%
print len(check_city.keys())
print len(check_county.keys())
# Out:
# 77
# 352

# %% [markdown]
# ### Create test files
#
# Next 2 cells used to generate FDB test files.  Loaded these into pg_dev and then attached parent_ids and state names to them

# %%
#city_out = open('./city_adds.csv', 'a')
for (city_id, name) in check_city.iteritems():
    short_name = name[:-1]
    pretty_city = u"%s|%s\n" % (city_id, short_name)
    #city_out.write(pretty_city.encode('utf8'))
#city_out.close()

# %%
#county_out = open('./county_adds.csv', 'a')
for (county_id, name) in check_county.iteritems():
    short_name = name[:-1]
    pretty_county = u"%s|%s\n" % (county_id, short_name)
    #county_out.write(pretty_county.encode('utf8'))
#county_out.close()

# %% [markdown]
# ### Create SQL insert statements
#
# Copied and pasted the output from this cell into a SQL file that I ran against pg_dev afterwards.

# %%
def create_name_insert(name_rec, feat_type):
    (feat_id, name) = name_rec
    #insert into names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) 
    #VALUES (1093602, 'Tiemenguan City', 10, False, 1, null, 'synonym', 'CHN', '694570');
    for map_code in ['1','2','3']:
        tfs_id = '694569'
        short_name = name[:-1]
        print ('INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) ' 
               'VALUES (%s, \'%s\', %s, False, %s, null, \'synonym\', \'CHN\', \'%s\');') % (feat_id, short_name, feat_type, map_code, tfs_id)
    
for rec in check_city.iteritems():
    create_name_insert(rec, '10')
    
for rec in check_county.iteritems():
    create_name_insert(rec, '2')
# Out:
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093428, '贺州', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093428, '贺州', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093428, '贺州', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093429, '呼伦贝尔', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093429, '呼伦贝尔', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093429, '呼伦贝尔', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456807, '富拉尔基', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456807, '富拉尔基', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456807, '富拉尔基', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093420, '鄂尔多斯', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093420, '鄂尔多斯', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093420, '鄂尔多斯', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093421, '抚州', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093421, '抚州', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093421, '抚州', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093422, '阜新', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093422, '阜新', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093422, '阜新', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093423, '赣州', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093423, '赣州', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093423, '赣州', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093424, '固原', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093424, '固原', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093424, '固原', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093425, '广安', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093425, '广安', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093425, '广安', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093426, '海东', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093426, '海东', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093426, '海东', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093427, '河池', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093427, '河池', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093427, '河池', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093414, '保山', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093414, '保山', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093414, '保山', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093417, '儋州', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093417, '儋州', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093417, '儋州', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093416, '崇左', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093416, '崇左', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093416, '崇左', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093411, '巴彦淖尔', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093411, '巴彦淖尔', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093411, '巴彦淖尔', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093410, '图木舒克', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093410, '图木舒克', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093410, '图木舒克', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093413, '宝鸡', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093413, '宝鸡', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093413, '宝鸡', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093412, '巴中', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093412, '巴中', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093412, '巴中', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456132, '淮安', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456132, '淮安', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456132, '淮安', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093419, '东方', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093419, '东方', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093419, '东方', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093418, '定西', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093418, '定西', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093418, '定西', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093389, '山南', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093389, '山南', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093389, '山南', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093402, '十堰', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093402, '十堰', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093402, '十堰', 10, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093403, '朔州', 10, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1093403, '朔州', 10, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (1
 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455745, '博尔塔拉蒙古自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455745, '博尔塔拉蒙古自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455745, '博尔塔拉蒙古自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456477, '甘南藏族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456477, '甘南藏族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456477, '甘南藏族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455743, '昌吉回族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455743, '昌吉回族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455743, '昌吉回族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455675, '怒江傈僳族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455675, '怒江傈僳族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455675, '怒江傈僳族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455741, '哈密地', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455741, '哈密地', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455741, '哈密地', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456378, '黄山', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456378, '黄山', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456378, '黄山', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7300, '荆州', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7300, '荆州', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7300, '荆州', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455674, '林芝地', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455674, '林芝地', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455674, '林芝地', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456278, '连云港', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456278, '连云港', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456278, '连云港', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456274, '聊城', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456274, '聊城', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456274, '聊城', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456271, '丽江', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456271, '丽江', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456271, '丽江', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455691, '迪庆藏族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455691, '迪庆藏族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455691, '迪庆藏族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455690, '果洛藏族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455690, '果洛藏族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455690, '果洛藏族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455693, '德宏傣族景颇族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455693, '德宏傣族景颇族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455693, '德宏傣族景颇族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455694, '保山', 2, False, 1, null, 'synonym', 'CHN', '694569');
# ...
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455915, '信阳', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455915, '信阳', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455664, '玉树藏族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455664, '玉树藏族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455664, '玉树藏族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455666, '日喀则地', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455666, '日喀则地', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455666, '日喀则地', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455669, '山南地', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455669, '山南地', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455669, '山南地', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456201, '南昌', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456201, '南昌', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456201, '南昌', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456439, '邯鄲', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456439, '邯鄲', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456439, '邯鄲', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456432, '汉中', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456432, '汉中', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456432, '汉中', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456436, '杭州', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456436, '杭州', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456436, '杭州', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455984, '温州', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455984, '温州', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455984, '温州', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455986, '文山壮族苗族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455986, '文山壮族苗族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455986, '文山壮族苗族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455980, '乌海', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455980, '乌海', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455980, '乌海', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455822, '枣庄', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455822, '枣庄', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455822, '枣庄', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455826, '玉溪', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455826, '玉溪', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455826, '玉溪', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456507, '东营', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456507, '东营', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456507, '东营', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456500, '恩施土家族苗族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456500, '恩施土家族苗族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456500, '恩施土家族苗族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7285, '西安', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7285, '西安', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (7285, '西安', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455958, '襄阳', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455958, '襄阳', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455958, '襄阳', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456145, '莆田', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456145, '莆田', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456145, '莆田', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456140, '潜江', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456140, '潜江', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456140, '潜江', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456142, '黔东南苗族侗族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456142, '黔东南苗族侗族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456142, '黔东南苗族侗族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456068, '石家庄', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456068, '石家庄', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456068, '石家庄', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456061, '十堰', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456061, '十堰', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456061, '十堰', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456615, '保亭黎族苗族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456615, '保亭黎族苗族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456615, '保亭黎族苗族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456617, '宝鸡', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456617, '宝鸡', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456617, '宝鸡', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456619, '保定', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456619, '保定', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456619, '保定', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456755, '牡丹江', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456755, '牡丹江', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456755, '牡丹江', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455956, '湘潭', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455956, '湘潭', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455956, '湘潭', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455954, '湘西土家族苗族自治', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455954, '湘西土家族苗族自治', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455954, '湘西土家族苗族自治', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455893, '延安', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455893, '延安', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455893, '延安', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455891, '盐城', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455891, '盐城', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455891, '盐城', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456207, '绵阳', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456207, '绵阳', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (456207, '绵阳', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455895, '徐州', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455895, '徐州', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455895, '徐州', 2, False, 3, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455894, '雅安', 2, False, 1, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455894, '雅安', 2, False, 2, null, 'synonym', 'CHN', '694569');
# INSERT INTO names (id, name, class, "default", map_code, language_code, type, iso3, tfs_id) VALUES (455894, '雅安', 2, False, 3, null, 'synonym', 'CHN', '694569');
